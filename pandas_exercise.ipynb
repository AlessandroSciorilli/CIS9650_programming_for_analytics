# %% [markdown]
# # Pandas Exercise
# >Import **ccbill_hw.csv** into a dataframe and plot the graph

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#1. Import ccbill_hw.csv into a dataframe
df = pd.read_csv('C:\\Users\\aless\\Desktop\\Second Python Assignment\\ccbill_hw.csv')

# %%
#2. Plot the graph in one line:
df.groupby("STORE")["AMOUNT"].sum().sort_values(ascending=True).plot (kind="barh", color="orange", grid=True)
# Out:
# <Axes: ylabel='STORE'>
